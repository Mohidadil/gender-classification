# %%
! kaggle datasets download cashutosh/gender-classification-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/cashutosh/gender-classification-dataset
# License(s): other
# gender-classification-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/gender-classification-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
train_path = '/content/Training'
test_path = '/content/Validation'

# %%
import os

# %%
len(os.listdir('/content/Training/female'))+len(os.listdir('/content/Training/male'))
# Out:
# 47009

# %%
len(os.listdir('/content/Validation/female'))+len(os.listdir('/content/Validation/male'))
# Out:
# 11649

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
gen=ImageDataGenerator(
    rescale=1./255,
)

# %%
train_images=gen.flow_from_directory(
    train_path,
    target_size=(180,180),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 47009 images belonging to 2 classes.

# %%
test_images=gen.flow_from_directory(
    test_path,
    target_size=(180,180),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 11649 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

# %%
train_images.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
plt.imshow(train_images[0][0][0])

# %%
plt.imshow(train_images[0][0][1])

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.applications.vgg16 import VGG16

# %%
vgg=VGG16(
    include_top=False,
    input_shape=(180,180,3)
)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 180, 180, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 180, 180, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 90, 90, 64)          │               0 │
# ...

# %%
vgg.trainable=False

# %%
model=Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(220,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,epochs=10)
# Out:
# Epoch 1/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 148s 100ms/step - accuracy: 0.9596 - loss: 0.1094
# Epoch 2/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 202s 100ms/step - accuracy: 0.9637 - loss: 0.0992
# Epoch 3/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 148s 100ms/step - accuracy: 0.9674 - loss: 0.0891
# Epoch 4/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 147s 100ms/step - accuracy: 0.9709 - loss: 0.0811
# Epoch 5/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 147s 100ms/step - accuracy: 0.9747 - loss: 0.0704
# Epoch 6/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 147s 100ms/step - accuracy: 0.9719 - loss: 0.0716
# Epoch 7/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 148s 100ms/step - accuracy: 0.9775 - loss: 0.0610
# Epoch 8/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 148s 100ms/step - accuracy: 0.9810 - loss: 0.0526
# Epoch 9/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 147s 100ms/step - accuracy: 0.9826 - loss: 0.0474
# Epoch 10/10
# 1470/1470 ━━━━━━━━━━━━━━━━━━━━ 202s 100ms/step - accuracy: 0.9834 - loss: 0.0434

# %%
model.save('model_13_epoch.h5')
from google.colab import files
files.download('model_13_epoch.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.evaluate(test_images)
# Out:
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 37s 102ms/step - accuracy: 0.9542 - loss: 0.1384
# [0.15389831364154816, 0.9510687589645386]

# %%
import cv2

# %%
model.predict(test_images)
# Out:
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step
# array([[9.9961531e-01],
#        [8.1794369e-08],
#        [9.9999595e-01],
#        ...,
#        [4.7419281e-08],
#        [9.9992621e-01],
#        [9.9999988e-01]], dtype=float32)

# %%
image_path="/content/download (8).jpeg"

# %%
image=cv2.imread(image_path)

# %%
image
# Out:
# array([[[ 73,  68,  43],
#         [ 72,  68,  44],
#         [ 69,  65,  46],
#         ...,
#         [ 82,  94,  96],
#         [ 81,  90,  93],
#         [ 79,  88,  91]],
#
#        [[ 77,  73,  45],
#         [ 76,  72,  47],
#         [ 73,  70,  49],
#         ...,
#         [ 84,  96,  98],
#         [ 82,  91,  94],
#         [ 80,  89,  92]],
#
#        [[ 86,  80,  51],
#         [ 84,  80,  52],
#         [ 82,  78,  54],
#         ...,
#         [ 88, 100, 102],
#         [ 85,  94,  97],
#         [ 81,  90,  93]],
#
#        ...,
#
#        [[240, 239, 241],
#         [239, 240, 244],
#         [239, 239, 245],
#         ...,
#         [ 63,  74,  88],
#         [106, 119, 133],
#         [150, 163, 177]],
#
#        [[242, 241, 243],
#         [240, 239, 241],
#         [234, 235, 239],
#         ...,
#         [ 52,  63,  77],
#         [ 92, 105, 119],
#         [139, 152, 166]],
#
#        [[236, 235, 237],
#         [233, 232, 234],
#         [226, 227, 231],
# ...

# %%
image=cv2.resize(image,(180,180))

# %%
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
image
# Out:
# array([[[ 43,  68,  73],
#         [ 45,  66,  70],
#         [ 45,  59,  58],
#         ...,
#         [101, 104,  87],
#         [ 95,  93,  82],
#         [ 92,  88,  79]],
#
#        [[ 46,  73,  77],
#         [ 49,  70,  74],
#         [ 49,  64,  63],
#         ...,
#         [106, 107,  91],
#         [ 97,  95,  83],
#         [ 92,  90,  81]],
#
#        [[ 51,  80,  86],
#         [ 54,  79,  82],
#         [ 53,  71,  72],
#         ...,
#         [114, 114,  98],
#         [101,  99,  87],
#         [ 94,  91,  82]],
#
#        ...,
#
#        [[242, 239, 239],
#         [245, 239, 239],
#         [244, 238, 235],
#         ...,
#         [ 38,  27,  22],
#         [ 98,  84,  72],
#         [166, 152, 139]],
#
#        [[242, 240, 241],
#         [239, 236, 235],
#         [237, 230, 230],
#         ...,
#         [ 57,  46,  41],
#         [ 86,  72,  61],
#         [154, 140, 127]],
#
#        [[236, 234, 235],
#         [231, 228, 227],
#         [228, 221, 221],
# ...

# %%
image_pred=model.predict(image.reshape(1,180,180,3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
import numpy as np
np.where(image_pred > 0.5 , 'Male' , 'Female' )
# Out:
# array([['Male']], dtype='<U6')

# %%
train_images.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
pip install gradio

# %%
import gradio

# %%
def app(image):
  image=image
  image=cv2.resize(image,(180,180))
  image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  #image=image/255.0
  image_pred=model.predict(image.reshape(1,180,180,3))
  pred=np.where(image_pred > 0.5 , "Male","Female")[0][0]

  return str(pred)

# %%
gradio.Interface(fn=app,inputs=["image"],outputs=["label"]).launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d740bbb525e2d880a7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d740bbb525e2d880a7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
